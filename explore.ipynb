# %%
# import pydytuesday

# pydytuesday.get_date('2025-08-12')

# %%
import pandas as pd

data = pd.read_csv('attribution_studies.csv')

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 744 entries, 0 to 743
# Data columns (total 14 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   event_name         744 non-null    object
#  1   event_period       735 non-null    object
#  2   event_year         592 non-null    object
#  3   study_focus        744 non-null    object
#  4   iso_country_code   520 non-null    object
#  5   cb_region          744 non-null    object
#  6   event_type         744 non-null    object
#  7   classification     744 non-null    object
#  8   summary_statement  744 non-null    object
#  9   publication_year   744 non-null    int64
#  10  citation           743 non-null    object
#  11  source             744 non-null    object
#  12  rapid_study        744 non-null    object
#  13  link               744 non-null    object
# dtypes: int64(1), object(13)
# memory usage: 81.5+ KB

# %%
data.study_focus.value_counts()
# Out:
# study_focus
# Event    593
# Trend    151
# Name: count, dtype: int64

# %%
(
    data[['publication_year']]
    .value_counts()
    .reset_index()
    .sort_values(by='publication_year', ascending=True)
)
# Out:
#     publication_year  count
# 17              2004      1
# 15              2005      1
# 16              2006      1
# 14              2007      3
# 12              2011     10
# 13              2012      9
# 11              2013     31
# 10              2014     32
# 6               2015     58
# 4               2016     62
# 7               2017     41
# 3               2018     80
# 9               2019     35
# 8               2020     41
# 1               2021     92
# 0               2022     95
# 5               2023     61
# 2               2024     91

# %%
data.event_type.value_counts()
# Out:
# event_type
# Heat                207
# Rain & flooding     177
# Drought             106
# Storm                61
# Cold, snow & ice     57
# Impact               33
# Compound             33
# Wildfire             31
# Oceans               25
# Atmosphere            7
# Sunshine              4
# River flow            3
# Name: count, dtype: int64

# %%
data.cb_region.value_counts()
# Out:
# cb_region
# Europe                              165
# Eastern and south-eastern Asia      161
# Northern America                    137
# Global                               63
# Sub-Saharan Africa                   56
# Australia and New Zealand            49
# Central and southern Asia            36
# Latin America and the Caribbean      32
# Northern hemisphere                  15
# Arctic                               11
# Northern Africa and western Asia      8
# Oceania                               8
# Antarctica                            3
# Name: count, dtype: int64

# %%
data.iso_country_code
# Out:
# 0      NaN
# 1      NaN
# 2      NaN
# 3      NaN
# 4      RUS
#       ...
# 739    CHN
# 740    CHN
# 741    AUS
# 742    NaN
# 743    CHN
# Name: iso_country_code, Length: 744, dtype: object

# %%
data
# Out:
#                                             event_name event_period  \
# 0                             European summer heatwave         2003
# 1                          Global temperature extremes   since 1950
# 2                         Record warm autumn in Europe         2006
# 3    Increasing frequency of 'very warm' Northern h...    1860-2009
# 4                               Moscow summer heatwave         2010
# ..                                                 ...          ...
# 739            China growing season hot and dry events    mid 1990s
# 740                               China hot-wet events    1979-2014
# 741  Heat extremes behind bleaching of the Great Ba...   2020, 2024
# 742  Heat-related neonatal deaths in low- and middl...    2001-2019
# 743              Hospitalisations in China due to heat    2000-2019
#
#            event_year study_focus iso_country_code  \
# 0                2003       Event              NaN
# ...
